# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
Image(r"Output2/Skincare/Micellar water/Cleansing oil/IMG_20230722_141423__01.png")

# %%
output = reader.readtext(r"Output2/Skincare/Micellar water/Cleansing oil/IMG_20230722_141423__01.png") //specify path to your image.

# %%
output
# Out:
# [([[192, 244], [360, 244], [360, 270], [192, 270]],
#   'GARNICR',
#   0.49850408852287953),
#  ([[276, 266], [350, 266], [350, 274], [276, 274]],
#   'N ETURAL',
#   0.24947543706697267),
#  ([[196, 294], [304, 294], [304, 318], [196, 318]],
#   'Micellar',
#   0.9999374954145189),
#  ([[198, 310], [332, 310], [332, 334], [198, 334]],
#   'Cleansing',
#   0.946962460638239),
#  ([[235, 333], [299, 333], [299, 347], [235, 347]],
#   'erinoil',
#   0.8008326601403135),
#  ([[249, 349], [311, 349], [311, 361], [249, 361]],
#   'BKIn TYPES',
#   0.1561263786497192),
#  ([[285, 361], [331, 361], [331, 379], [285, 379]],
#   'arsoo"',
#   0.17337950714480452),
#  ([[210, 386], [274, 386], [274, 392], [210, 392]],
#   'LCrIteati  10pr',
#   7.219054930088638e-05),
#  ([[298, 384], [322, 384], [322, 390], [298, 390]],
#   'leheaal',
#   0.015006843016836446),
#  ([[288, 436], [318, 436], [318, 444], [288, 444]], 'u', 0.2895153728666777),
# ...
